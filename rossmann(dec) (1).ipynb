# %%
import pandas as pd

# %%
ross_df = pd.read_csv("data/train.csv (1).zip",low_memory=False)
store_df=pd.read_csv("data/store.csv")
#test_df=pd.read_csv("data/test.csv.zip")
#submission_df=pd.read_csv(r"C:\Users\gnan\Downloads\sample_submission (1).csv")

# %%
ross_df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %%
store_df
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# ...

# %%
merge_df=ross_df.merge(store_df,how='left',on='Store')
#merged_test_df=test_df.merge(store_df,how='left',on='Store')

# %%
merge_df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %% [markdown]
# ## Preprocessing data and feature engineering

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Date                       1017209 non-null  object
#  3   Sales                      1017209 non-null  int64
#  4   Customers                  1017209 non-null  int64
#  5   Open                       1017209 non-null  int64
#  6   Promo                      1017209 non-null  int64
#  7   StateHoliday               1017209 non-null  object
#  8   SchoolHoliday              1017209 non-null  int64
#  9   StoreType                  1017209 non-null  object
#  10  Assortment                 1017209 non-null  object
#  11  CompetitionDistance        1014567 non-null  float64
#  12  CompetitionOpenSinceMonth  693861 non-null   float64
# ...

# %% [markdown]
# #### Data

# %%
def split_date(df):
    df['Date']=pd.to_datetime(df['Date'])
    df['Year']=df.Date.dt.year
    df['Month']=df.Date.dt.month
    df['Day']=df.Date.dt.day
    df['weekofyear']=df.Date.dt.isocalendar().week

# %%
split_date(merge_df)
#split_date(merged_test_df)

# %%
merge_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1111          2 2013-01-01      0          0     0      0
# 1017205   1112          2 2013-01-01      0          0     0      0
# 1017206   1113          2 2013-01-01      0          0     0      0
# 1017207   1114          2 2013-01-01      0          0     0      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType  ... CompetitionOpenSinceMonth  \
# ...

# %% [markdown]
# ### Store open/close

# %%
merge_df[merge_df.Open==0].Sales.value_counts()
# Out:
# Sales
# 0    172817
# Name: count, dtype: int64

# %%
merge_df=merge_df[merge_df.Open==1].copy()

# %%
merge_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1016776    682          2 2013-01-01   3375        566     1      0
# 1016827    733          2 2013-01-01  10765       2377     1      0
# 1016863    769          2 2013-01-01   5035       1248     1      0
# 1017042    948          2 2013-01-01   4491       1039     1      0
# 1017190   1097          2 2013-01-01   5961       1405     1      0
#
#         StateHoliday  SchoolHoliday StoreType  ... CompetitionOpenSinceMonth  \
# ...

# %% [markdown]
# ### Competation

# %%
def competation(df):
    df['CompetationOpen']=(df.Year-df.CompetitionOpenSinceYear)*12 + (df.Month-df.CompetitionOpenSinceMonth)
    df['CompetationOpen']=df['CompetationOpen'].map(lambda x: 0 if x<0 else x).fillna(0)

# %%
competation(merge_df)
#competation(merged_test_df)
#merge_df

# %%
pd.set_option('display.max_columns', None) ## to display all columns data preventing data from hiding happens when col are more

# %% [markdown]
# ### Promo

# %%
#def cal_promo(df):
#   df['Promotime']=12*(df.Year - df.Promo2SinceYear) + (

# %% [markdown]
# ### Input and Target Columns

# %%
merge_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval', 'Year', 'Month', 'Day',
#        'weekofyear', 'CompetationOpen'],
#       dtype='object')

# %%
input_cols = ['Store', 'DayOfWeek', 'Promo', 'StateHoliday', 'SchoolHoliday', 
              'StoreType', 'Assortment', 'CompetitionDistance', 'CompetationOpen', 
              'Day', 'Month', 'Year', 'weekofyear',  'Promo2']
target_col = 'Sales'

# %%
inputs = merge_df[input_cols].copy()
targets = merge_df[target_col].copy()

# %%
inputs
# Out:
#          Store  DayOfWeek  Promo StateHoliday  SchoolHoliday StoreType  \
# 0            1          5      1            0              1         c
# 1            2          5      1            0              1         a
# 2            3          5      1            0              1         a
# 3            4          5      1            0              1         c
# 4            5          5      1            0              1         a
# ...        ...        ...    ...          ...            ...       ...
# 1016776    682          2      0            a              1         b
# 1016827    733          2      0            a              1         b
# 1016863    769          2      0            a              1         b
# 1017042    948          2      0            a              1         b
# 1017190   1097          2      0            a              1         b
#
#         Assortment  CompetitionDistance  CompetationOpen  Day  Month  Year  \
# ...

# %%
targets
# Out:
# 0           5263
# 1           6064
# 2           8314
# 3          13995
# 4           4822
#            ...
# 1016776     3375
# 1016827    10765
# 1016863     5035
# 1017042     4491
# 1017190     5961
# Name: Sales, Length: 844392, dtype: int64

# %% [markdown]
# ### Impute missing numerical data

# %%
numeric_cols = ['Store', 'Promo', 'SchoolHoliday', 
              'CompetitionDistance', 'CompetationOpen', 'Promo2',
              'Day', 'Month', 'Year', 'weekofyear']
categorical_cols = ['DayOfWeek', 'StateHoliday', 'StoreType', 'Assortment']

# %%
inputs[numeric_cols].isna().sum()
# Out:
# Store                     0
# Promo                     0
# SchoolHoliday             0
# CompetitionDistance    2186
# CompetationOpen           0
# Promo2                    0
# Day                       0
# Month                     0
# Year                      0
# weekofyear                0
# dtype: int64

# %%
max_distance = inputs.CompetitionDistance.max()
max_distance
# Out:
# np.float64(75860.0)

# %%
inputs['CompetitionDistance']=inputs['CompetitionDistance'].fillna(max_distance*2)
#test_inputs['CompetitionDistance']=test_inputs['CompetitionDistance'].fillna(max_distance*2)
#test_inputs

# %% [markdown]
# ### Scalling numeric data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler().fit(inputs[numeric_cols])

# %%
inputs[numeric_cols]=scaler.transform(inputs[numeric_cols])
#test_inputs[numeric_cols]=scaler.transform(test_inputs[numeric_cols])

# %% [markdown]
# ### Encode categorical columns

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder=OneHotEncoder(sparse_output=False,handle_unknown='ignore').fit(inputs[categorical_cols])
encoded_cols=list(encoder.get_feature_names_out(categorical_cols))

# %%
inputs[encoded_cols]=encoder.transform(inputs[categorical_cols])
#test_inputs[encoded_cols]=encoder.transform(test_inputs[categorical_cols])

# %%
x=inputs[numeric_cols+encoded_cols]
#x_test=test_inputs[numeric_cols+encoded_cols]

# %% [markdown]
# ### Training(XGboost)

# %%
from xgboost import XGBRegressor

# %%
model=XGBRegressor(random_state=42,n_jobs=-1,n_estimators=20,max_depth=4)

# %%
x.columns
# Out:
# Index(['Store', 'Promo', 'SchoolHoliday', 'CompetitionDistance',
#        'CompetationOpen', 'Promo2', 'Day', 'Month', 'Year', 'weekofyear',
#        'DayOfWeek_1', 'DayOfWeek_2', 'DayOfWeek_3', 'DayOfWeek_4',
#        'DayOfWeek_5', 'DayOfWeek_6', 'DayOfWeek_7', 'StateHoliday_0',
#        'StateHoliday_a', 'StateHoliday_b', 'StateHoliday_c', 'StoreType_a',
#        'StoreType_b', 'StoreType_c', 'StoreType_d', 'Assortment_a',
#        'Assortment_b', 'Assortment_c'],
#       dtype='object')

# %%
# %%time
model.fit(x,targets)
# Out:
# CPU times: user 3.11 s, sys: 62.9 ms, total: 3.17 s
# Wall time: 2.41 s
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=20,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
preds=model.predict(x)

# %%
preds
# Out:
# array([8021.996 , 7663.2285, 8584.852 , ..., 7540.903 , 7539.4336,
#        9778.964 ], shape=(844392,), dtype=float32)

# %% [markdown]
# ### evaluation

# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
def rmse(a,b):
    return np.sqrt(mean_squared_error(a,b))

# %%
rmse(targets,preds)
# Out:
# np.float64(2399.4728587754435)

# %% [markdown]
# ### Feature importance

# %%
importance_df=pd.DataFrame({
    'feature':x.columns,
    'importance':model.feature_importances_
}).sort_values('importance',ascending=False)

# %%
importance_df.head(10)
# Out:
#                 feature  importance
# 1                 Promo    0.431753
# 10          DayOfWeek_1    0.090702
# 22          StoreType_b    0.069578
# 25         Assortment_a    0.051793
# 5                Promo2    0.044245
# 3   CompetitionDistance    0.035661
# 24          StoreType_d    0.033135
# 9            weekofyear    0.028942
# 7                 Month    0.026356
# 11          DayOfWeek_2    0.025761

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
plt.title('Feature Importance')
sns.barplot(data=importance_df.head(10), x='importance', y='feature');

# %% [markdown]
# ### K Fold cross validation

# %%
#copy & paste kaleya

# %%
from sklearn.model_selection import KFold

# %%
def train_and_evaluate(X_train, train_targets, X_val, val_targets, **params):
    model = XGBRegressor(random_state=42, n_jobs=-1, **params)
    model.fit(X_train, train_targets)
    train_rmse = rmse(model.predict(X_train), train_targets)
    val_rmse = rmse(model.predict(X_val), val_targets)
    return model, train_rmse, val_rmse

# %%
kfold = KFold(n_splits=5)

# %%
models = []

for train_idxs, val_idxs in kfold.split(x):
    x_train, train_targets = x.iloc[train_idxs], targets.iloc[train_idxs]
    x_val, val_targets = x.iloc[val_idxs], targets.iloc[val_idxs]
    model, train_rmse, val_rmse = train_and_evaluate(x_train, 
                                                     train_targets, 
                                                     x_val, 
                                                     val_targets, 
                                                     max_depth=4, 
                                                     n_estimators=20)
    models.append(model)
    print('Train RMSE: {}, Validation RMSE: {}'.format(train_rmse, val_rmse))
# Out:
# Train RMSE: 2390.1668351811763, Validation RMSE: 2453.38857501212
# Train RMSE: 2400.904204669566, Validation RMSE: 2448.215166197612
# Train RMSE: 2364.271452266004, Validation RMSE: 2347.3021748381693
# Train RMSE: 2354.1823421307026, Validation RMSE: 2466.1921052505218
# Train RMSE: 2390.7836581338765, Validation RMSE: 2438.969659507883

# %%
import numpy as np

def predict_avg(models, inputs):
    return np.mean([model.predict(inputs) for model in models], axis=0)

# %%
preds = predict_avg(models,x)

# %%
preds
# Out:
# array([7832.464, 7549.495, 8554.099, ..., 8262.4  , 7457.022, 9729.517],
#       shape=(844392,), dtype=float32)

# %% [markdown]
# ### Hypermeter Tuning

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_val,train_targets,val_targets=train_test_split(x,targets,test_size=0.1)#the validation set is taken 10% in whole training data so test_size =0.1

# %%
def test_params(**params):
    model=XGBRegressor(n_jobs=-1,random_state=42,**params)
    model.fit(x_train,train_targets)
    train_rmse=rmse(model.predict(x_train),train_targets)
    val_rmse=rmse(model.predict(x_val),val_targets)
    print('Train rmse: {},Val rmse :{}'.format(train_rmse,val_rmse))

# %% [markdown]
# ### n_estimators
# The number of trees to be created. More trees = greater capacity of the model.

# %%
test_params(n_estimators=10)
# Out:
# Train rmse: 2318.1089275528016,Val rmse :2325.1178464757436

# %% [markdown]
# ### max_depth
# As you increase the max depth of each tree, the capacity of the tree increases and it can capture more information about the training set.

# %%
test_params(max_depth=2,n_estimators=50)
# Out:
# Train rmse: 2490.558069991543,Val rmse :2497.655600758439

# %% [markdown]
# ### learning_rate
# The scaling factor to be applied to the prediction of each tree. A very high learning rate (close to 1) will lead to overfitting, and a low learning rate (close to 0) will lead to underfitting.

# %%
test_params(n_estimators=50, learning_rate=0.01)
# Out:
# Train rmse: 2789.9913082301887,Val rmse :2787.2877497667873

# %%
test_params(n_estimators=50, learning_rate=0.1)
# Out:
# Train rmse: 2206.9985274122864,Val rmse :2218.563499203933

# %%
test_params(n_estimators=50, learning_rate=0.99)
# Out:
# Train rmse: 1189.240829268824,Val rmse :1203.7612927819202

# %% [markdown]
# ### booster
# Instead of using Decision Trees, XGBoost can also train a linear model for each iteration. This can be configured using booster.

# %%
model = XGBRegressor(n_jobs=-1, random_state=42, n_estimators=1000, 
                     learning_rate=0.2, max_depth=10, subsample=0.9, 
                     colsample_bytree=0.7)

# %%
# %%time
model.fit(x, targets)
# Out:
# CPU times: user 2min 9s, sys: 407 ms, total: 2min 10s
# Wall time: 1min 11s
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=10,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
import joblib

joblib.dump(model, "rossmann_model.pkl")

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
import joblib

# %%
# columns given by user
date_column = ["Date"]

numeric_features = [
    "Store",
    "Promo",
    "SchoolHoliday",
    "CompetitionDistance",
    "Promo2"
]

categorical_features = [
    "StateHoliday",
    "StoreType",
    "Assortment"
]

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler

preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ]
)

# %%
pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", model)
    ]
)

# %%
x_df=ross_df.merge(store_df,how='left',on='Store')

# %%
y_final= x_df["Sales"]
x_final=x_df.drop(columns=["Sales"])

# %%
y_final
# Out:
# 0           5263
# 1           6064
# 2           8314
# 3          13995
# 4           4822
#            ...
# 1017204        0
# 1017205        0
# 1017206        0
# 1017207        0
# 1017208        0
# Name: Sales, Length: 1017209, dtype: int64

# %%
pipeline.fit(x_final,y_final)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Store', 'Promo',
#                                                    'SchoolHoliday',
#                                                    'CompetitionDistance',
#                                                    'Promo2']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['StateHoliday', 'StoreType',
#                                                    'Assortment'])])),
#                 ('model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynod...
#                               feature_types=None, feature_weights=None,
# ...

# %%
import pandas as pd
from sklearn.base import BaseEstimator, TransformerMixin

# %%
from transformers import DateFeatureExtractor

# %%
numeric_features = [
    "Store",
    "Promo",
    "SchoolHoliday",
    "CompetitionDistance",
    "CompetitionOpenSinceMonth",
    "CompetitionOpenSinceYear",
    "Promo2",
    "Promo2SinceWeek",
    "Promo2SinceYear",
    "Day",
    "Month",
    "Year",
    "WeekOfYear"
]

categorical_features = [
    "StateHoliday",
    "StoreType",
    "Assortment",
    "PromoInterval"
]

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ]
)

pipeline = Pipeline(
    steps=[
        ("date_features", DateFeatureExtractor()),
        ("preprocessor", preprocessor),
        ("model", model)
    ]
)

# %%
pipeline.fit(x_final, y_final)
# Out:
# Pipeline(steps=[('date_features', DateFeatureExtractor()),
#                 ('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Store', 'Promo',
#                                                    'SchoolHoliday',
#                                                    'CompetitionDistance',
#                                                    'CompetitionOpenSinceMonth',
#                                                    'CompetitionOpenSinceYear',
#                                                    'Promo2', 'Promo2SinceWeek',
#                                                    'Promo2SinceYear', 'Day',
#                                                    'Month', 'Year',
#                                                    'WeekOfYear']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_un...
# ...

# %%
import joblib
joblib.dump(pipeline, "rossmann_pipeline.pkl")
# Out:
# ['rossmann_pipeline.pkl']

# %%
import os
os.listdir()
# Out:
# ['.gitattributes',
#  '.git',
#  'transformers.py',
#  'templates',
#  'rossmann(dec) (1).ipynb',
#  'rossmann_pipeline.pkl',
#  'app.py',
#  '.gitignore',
#  '__pycache__',
#  'data',
#  'README.md',
#  'LICENSE']
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
